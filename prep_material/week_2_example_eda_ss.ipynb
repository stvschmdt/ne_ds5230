# %%
# dataset
#https://www.kaggle.com/datasets/andrewsundberg/college-basketball-dataset?resource=download

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('lecture2/cbb.csv')

# %%
data.columns
# Out:
# Index(['TEAM', 'CONF', 'G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D',
#        'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O',
#        '3P_D', 'ADJ_T', 'WAB', 'POSTSEASON', 'SEED', 'YEAR'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3523 entries, 0 to 3522
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM        3523 non-null   object
#  1   CONF        3523 non-null   object
#  2   G           3523 non-null   int64
#  3   W           3523 non-null   int64
#  4   ADJOE       3523 non-null   float64
#  5   ADJDE       3523 non-null   float64
#  6   BARTHAG     3523 non-null   float64
#  7   EFG_O       3523 non-null   float64
#  8   EFG_D       3523 non-null   float64
#  9   TOR         3523 non-null   float64
#  10  TORD        3523 non-null   float64
#  11  ORB         3523 non-null   float64
#  12  DRB         3523 non-null   float64
#  13  FTR         3523 non-null   float64
#  14  FTRD        3523 non-null   float64
#  15  2P_O        3523 non-null   float64
#  16  2P_D        3523 non-null   float64
#  17  3P_O        3523 non-null   float64
# ...

# %%
data.POSTSEASON.unique()
# Out:
# array(['2ND', 'Champions', 'E8', 'F4', nan, 'R32', 'R64', 'R68', 'S16'],
#       dtype=object)

# %%
# what should we do about nan?
data[data.POSTSEASON.isnull()]
# Out:
#                    TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 56             Duquesne   A10  30  11  107.0  111.7   0.3790   51.2   51.7
# 57              Fordham   A10  30   9  101.0  103.0   0.4450   46.7   50.2
# 58         George Mason   A10  30   8  101.2  103.8   0.4276   45.5   50.0
# 59    George Washington   A10  35  22  107.2   96.2   0.7755   48.9   45.9
# 60             La Salle   A10  33  17   98.9   92.9   0.6734   46.7   45.8
# ...                 ...   ...  ..  ..    ...    ...      ...    ...    ...
# 3518             Toledo   MAC  34  27  119.9  109.6   0.7369   56.3   52.9
# 3519            Liberty  ASun  33  27  111.4   97.3   0.8246   55.5   49.3
# 3520        Utah Valley   WAC  34  28  107.1   94.6   0.8065   51.7   44.0
# 3521                UAB  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3
# 3522        North Texas  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5
#
# ...

# %%
data.describe()
# Out:
#                  G            W        ADJOE        ADJDE      BARTHAG  \
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000
# mean     30.486233    15.990633   103.151320   103.153250     0.494067
# std       3.951584     6.572893     7.264859     6.511989     0.255338
# min       5.000000     0.000000    76.600000    84.000000     0.005000
# 25%      29.000000    11.000000    98.200000    98.400000     0.281300
# 50%      31.000000    16.000000   102.800000   103.200000     0.475600
# 75%      33.000000    21.000000   107.900000   107.800000     0.714250
# max      40.000000    38.000000   129.100000   124.000000     0.984200
#
#              EFG_O        EFG_D          TOR         TORD          ORB  ...  \
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000  ...
# mean     49.887823    50.087113    18.696509    18.625092    29.308544  ...
# std       3.078505     2.894967     2.104119     2.241067     4.214131  ...
# ...

# %%
data.groupby('TEAM').count()
# Out:
#                    CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  TOR  \
# TEAM
# Abilene Christian     9   9   9      9      9        9      9      9    9
# Air Force            10  10  10     10     10       10     10     10   10
# Akron                10  10  10     10     10       10     10     10   10
# Alabama              10  10  10     10     10       10     10     10   10
# Alabama A&M          10  10  10     10     10       10     10     10   10
# ...                 ...  ..  ..    ...    ...      ...    ...    ...  ...
# Wright St.           10  10  10     10     10       10     10     10   10
# Wyoming              10  10  10     10     10       10     10     10   10
# Xavier               10  10  10     10     10       10     10     10   10
# Yale                  9   9   9      9      9        9      9      9    9
# Youngstown St.       10  10  10     10     10       10     10     10   10
#
#                    TORD  ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T  WAB  \
# ...

# %%
data.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3      Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4         Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2  ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3  ...  36.6  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019
# 4  ...  26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
#
# [5 rows x 24 columns]

# %%
averages = data[['CONF', 'G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D',
       'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O',
       '3P_D', 'ADJ_T', 'WAB']].groupby('CONF').mean()

# %%
averages.hist()
plt.show()

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(averages.corr(), annot=True, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(averages.cov(), annot=True, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
plt.scatter(data.ADJOE, data.ADJDE)
plt.show()

# %%
first_rounds = data[(data.POSTSEASON =='R64') | (data.POSTSEASON == 'R32')]

# %%
final_rounds = data[(data.POSTSEASON == 'Champions') | (data.POSTSEASON == 'F4') | (data.POSTSEASON == 'E8') | (data.POSTSEASON == 'S16')]

# %%
final_rounds
# Out:
#                   TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 7                 Duke   ACC  39  35  125.2   90.6   0.9764   56.6   46.5
# 8             Virginia   ACC  38  35  123.0   89.9   0.9736   55.2   44.7
# 9       North Carolina   ACC  39  33  121.0   91.5   0.9615   51.7   48.1
# 10           Villanova    BE  40  35  123.1   90.9   0.9703   56.1   46.7
# 11           Villanova    BE  40  36  128.4   94.1   0.9725   59.5   48.5
# ...                ...   ...  ..  ..    ...    ...      ...    ...    ...
# 3180         Creighton    BE  37  24  115.0   93.2   0.9177   54.2   47.1
# 3187      Michigan St.   B10  34  21  114.4   96.4   0.8771   51.7   48.6
# 3191          Arkansas   SEC  36  22  111.9   93.3   0.8894   50.9   47.2
# 3192  Florida Atlantic  CUSA  37  35  114.0   95.8   0.8815   54.3   46.1
# 3221         Princeton   Ivy  30  23  109.1  101.0   0.7083   52.2   48.4
#
#        TOR  ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  \
# ...

# %%
numerics = ['G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D',
       'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O',
       '3P_D', 'ADJ_T', 'WAB']
for col in numerics:
    plt.hist(first_rounds[col], label='first')
    plt.hist(final_rounds[col], label='finals')
    plt.legend()
    plt.title('{}'.format(col))
    plt.show()

# %%
final_rounds[numerics].mean() - first_rounds[numerics].mean()
# Out:
# G          2.887917
# W          4.169167
# ADJOE      5.961250
# ADJDE     -3.963375
# BARTHAG    0.138226
# EFG_O      1.137500
# EFG_D     -1.002792
# TOR       -0.550750
# TORD       0.123750
# ORB        1.521875
# DRB       -0.017958
# FTR       -0.766000
# FTRD      -1.727833
# 2P_O       1.164958
# 2P_D      -1.031167
# 3P_O       0.715875
# 3P_D      -0.580042
# ADJ_T     -0.023667
# WAB        4.597667
# dtype: float64

# %%
final_rounds[numerics].std() - first_rounds[numerics].std()
# Out:
# G          0.451374
# W          0.742878
# ADJOE     -0.587690
# ADJDE     -0.866614
# BARTHAG   -0.094442
# EFG_O      0.161643
# EFG_D      0.221070
# TOR       -0.198670
# TORD       0.282383
# ORB       -0.320551
# DRB       -0.343687
# FTR       -0.908123
# FTRD      -0.313137
# 2P_O       0.175232
# 2P_D      -0.001518
# 3P_O       0.080963
# 3P_D       0.314402
# ADJ_T      0.037895
# WAB       -0.805608
# dtype: float64

# %%
best_mean = final_rounds[numerics].mean()['ADJOE']

# %%
one_std = final_rounds[numerics].std()['ADJOE']

# %%
best_mean, one_std
# Out:
# (115.98, 5.018195081819222)

# %%
best_adjoe = final_rounds[numerics].mean()['ADJOE']

# %%
close = []
for idx, team in first_rounds.iterrows():
    if team['ADJOE'] > (best_mean + one_std):
        print(team.TEAM, best_mean+one_std, team.ADJOE, team.SEED, team.YEAR)
# Out:
# Duke 120.99819508181923 122.1 2.0 2017
# Villanova 120.99819508181923 121.9 1.0 2015
# Villanova 120.99819508181923 122.2 1.0 2017
# Kentucky 120.99819508181923 123.2 4.0 2016
# Creighton 120.99819508181923 125.2 3.0 2014
# Michigan St. 120.99819508181923 122.5 2.0 2016
# Oklahoma St. 120.99819508181923 126.8 10.0 2017
# Marquette 120.99819508181923 121.8 10.0 2017
# Duke 120.99819508181923 125.9 3.0 2014
# Iowa 120.99819508181923 123.5 2.0 2021
# Ohio St. 120.99819508181923 122.1 2.0 2021
# Iowa 120.99819508181923 121.1 5.0 2022
# Baylor 120.99819508181923 121.7 3.0 2023

# %%
pd.cut(data.ADJOE, 3, labels=["bad", "ok", "good"])
# Out:
# 0       good
# 1       good
# 2       good
# 3       good
# 4       good
#         ...
# 3518    good
# 3519      ok
# 3520      ok
# 3521    good
# 3522      ok
# Name: ADJOE, Length: 3523, dtype: category
# Categories (3, object): ['bad' < 'ok' < 'good']

# %%
pd.cut(data.ADJOE, 3, labels=["bad", "ok", "good"]).value_counts()
# Out:
# ADJOE
# ok      2747
# good     425
# bad      351
# Name: count, dtype: int64

# %%
pd.cut(data.ADJDE, 3, labels=["bad", "ok", "good"])
# Out:
# 0       bad
# 1       bad
# 2       bad
# 3       bad
# 4       bad
#        ...
# 3518     ok
# 3519    bad
# 3520    bad
# 3521    bad
# 3522    bad
# Name: ADJDE, Length: 3523, dtype: category
# Categories (3, object): ['bad' < 'ok' < 'good']

# %%
pd.cut(data.ADJDE, 3, labels=["bad", "ok", "good"]).value_counts()
# Out:
# ADJDE
# ok      2368
# bad      702
# good     453
# Name: count, dtype: int64

# %%
data[['CONF'] + numerics].groupby('CONF').mean().sort_values(by='ADJOE', ascending=False)
# Out:
#               G          W       ADJOE       ADJDE   BARTHAG      EFG_O  \
# CONF
# B12   33.420000  20.550000  111.787000   95.048000  0.839162  50.781000
# ACC   33.020408  19.673469  111.119048   97.076190  0.789014  51.057823
# B10   33.316176  19.911765  111.103676   95.880882  0.815229  50.755882
# BE    32.787037  19.564815  110.655556   96.625000  0.796529  50.956481
# SEC   32.971429  19.171429  109.342143   96.547143  0.775311  49.834286
# P12   32.783333  18.850000  108.749167   98.063333  0.737644  50.760833
# WCC   30.808081  17.303030  106.637374  101.027273  0.606746  51.102020
# Amer  31.510000  17.820000  106.338000   98.773000  0.660738  49.333000
# MWC   30.935185  17.351852  105.385185  100.584259  0.614011  50.310185
# A10   31.295775  16.985915  105.135211  100.177465  0.616326  50.007042
# MVC   31.245098  17.009804  103.552941  100.898039  0.556302  50.430392
# Ind   29.000000  17.000000  103.300000  104.500000  0.464400  52.300000
# ...

# %%
final_rounds.groupby('CONF').size().sort_values(ascending=False)
# Out:
# CONF
# ACC     28
# B10     21
# B12     21
# P12     20
# SEC     20
# BE      15
# Amer     6
# WCC      6
# MVC      4
# A10      2
# MWC      2
# ASun     1
# CUSA     1
# Ivy      1
# MAAC     1
# Sum      1
# dtype: int64

# %%
final_rounds[final_rounds.CONF == 'B12'].sort_values(by='ADJOE', ascending=False)
# Out:
#                TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 2456         Baylor  B12  24  22  123.2   94.5   0.9548   57.5   49.1  17.6
# 46           Kansas  B12  39  31  122.1   96.4   0.9385   57.5   49.1  16.6
# 23           Kansas  B12  36  31  121.5   94.5   0.9472   56.1   48.1  17.6
# 2419       Iowa St.  B12  35  23  121.4   98.6   0.9162   57.1   49.8  15.7
# 22           Kansas  B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8
# 2422  West Virginia  B12  37  26  120.9   95.8   0.9353   50.4   49.9  16.5
# 2803         Kansas  B12  40  34  119.8   91.3   0.9580   53.8   45.8  17.3
# 2444         Baylor  B12  36  24  119.2   99.5   0.8885   51.3   48.7  17.8
# 2440       Iowa St.  B12  36  28  118.6   98.8   0.8903   54.2   47.7  14.5
# 45         Oklahoma  B12  37  29  118.2   94.1   0.9326   54.3   47.2  18.3
# 2420         Baylor  B12  34  27  116.4   93.9   0.9226   52.5   46.1  20.6
# ...
